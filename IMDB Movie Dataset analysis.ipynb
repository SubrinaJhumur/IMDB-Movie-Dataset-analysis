# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\IMDB-Movie-Data.csv')

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
data.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
per_missing_data=(data.isnull().sum()*100)/len(data)

# %%
per_missing_data
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\IMDB-Movie-Data.csv')

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data['Metascore'].fillna(data['Metascore'].mean(),inplace=True)

# %%
data['Metascore'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore               0
# dtype: int64

# %%
data['Revenue (Millions)'].fillna(data['Revenue (Millions)'].mean(),inplace=True)

# %%
data['Revenue (Millions)'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.duplicated().any()
# Out:
# False

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)    Metascore
# count         1000.000000  1000.000000
# mean            82.956376    58.985043
# std             96.412043    16.634858
# min              0.000000    11.000000
# 25%             17.442500    47.750000
# ...

# %%
len(data[(data['Runtime (Minutes)']>=180)])
# Out:
# 5

# %%
data[(data['Runtime (Minutes)']>=180)]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %%
data['Runtime (Minutes)'].value_counts().sort_values(ascending=False)
# Out:
# Runtime (Minutes)
# 108    31
# 100    28
# 117    27
# 118    26
# 106    26
#        ..
# 187     1
# 160     1
# 82      1
# 191     1
# 145     1
# Name: count, Length: 94, dtype: int64

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    285226.093750
# 2008    275505.384615
# 2006    269289.954545
# 2009    255780.647059
# 2010    252782.316667
# 2007    244331.037736
# 2011    240790.301587
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='Year',y='Votes',data=data)
plt.show()

# %%
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    110.276186
# 2012    107.973281
# 2010    103.975319
# 2008     98.772623
# 2011     87.538355
# 2007     87.510481
# 2013     86.984496
# 2006     86.144835
# 2014     84.992097
# 2015     78.862278
# 2016     63.446588
# Name: Revenue (Millions), dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.show()

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data_10=data.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(10).plot(kind='barh')

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.nlargest(10,'Revenue (Millions)')
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 87     88                                      Avatar
# 85     86                              Jurassic World
# 76     77                                The Avengers
# 54     55                             The Dark Knight
# 12     13                                   Rogue One
# 119   120                                Finding Dory
# 94     95                     Avengers: Age of Ultron
# 124   125                       The Dark Knight Rises
# 578   579             The Hunger Games: Catching Fire
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 87     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 76                Action,Sci-Fi
# 54           Action,Crime,Drama
# 12      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 94      Action,Adventure,Sci-Fi
# 124             Action,Thriller
# 578    Action,Adventure,Mystery
#
# ...

# %%
data.nlargest(10,'Revenue (Millions)')[['Rank','Title','Year','Runtime (Minutes)', 'Rating','Revenue (Millions)']]
# Out:
#      Rank                                       Title  Year  \
# 50     51  Star Wars: Episode VII - The Force Awakens  2015
# 87     88                                      Avatar  2009
# 85     86                              Jurassic World  2015
# 76     77                                The Avengers  2012
# 54     55                             The Dark Knight  2008
# 12     13                                   Rogue One  2016
# 119   120                                Finding Dory  2016
# 94     95                     Avengers: Age of Ultron  2015
# 124   125                       The Dark Knight Rises  2012
# 578   579             The Hunger Games: Catching Fire  2013
#
#      Runtime (Minutes)  Rating  Revenue (Millions)
# 50                 136     8.1              936.63
# 87                 162     7.8              760.51
# 85                 124     7.0              652.18
# 76                 143     8.1              623.28
# ...

# %%
data1=data.nlargest(10,'Revenue (Millions)')[['Rank','Title','Year','Runtime (Minutes)', 'Rating','Revenue (Millions)']].set_index('Title')

# %%
data1.head(5)
# Out:
#                                             Rank  Year  Runtime (Minutes)  \
# Title
# Star Wars: Episode VII - The Force Awakens    51  2015                136
# Avatar                                        88  2009                162
# Jurassic World                                86  2015                124
# The Avengers                                  77  2012                143
# The Dark Knight                               55  2008                152
#
#                                             Rating  Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens     8.1              936.63
# Avatar                                         7.8              760.51
# Jurassic World                                 7.0              652.18
# The Avengers                                   8.1              623.28
# The Dark Knight                                9.0              533.32

# %%
plt.figure(figsize=(30,4))
sns.barplot(x='Title',y='Revenue (Millions)',data=data1)
plt.show()

# %%
data['Year'].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Year',data=data)
plt.show()

# %%
data_movies=data.groupby('Revenue (Millions)')['Title'].sum().sort_values(ascending=False).head(5)#.plot(kind='barh')

# %%
data['Revenue (Millions)'].max()
# Out:
# 936.63

# %%
data[data['Revenue (Millions)']==936.63]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
data[data['Revenue (Millions)']==936.63]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
data_5=data.nlargest(5,'Revenue (Millions)')[['Rank','Title','Year','Runtime (Minutes)', 'Rating']].set_index('Title')

# %%
data_5
# Out:
#                                             Rank  Year  Runtime (Minutes)  \
# Title
# Star Wars: Episode VII - The Force Awakens    51  2015                136
# Avatar                                        88  2009                162
# Jurassic World                                86  2015                124
# The Avengers                                  77  2012                143
# The Dark Knight                               55  2008                152
#
#                                             Rating
# Title
# Star Wars: Episode VII - The Force Awakens     8.1
# Avatar                                         7.8
# Jurassic World                                 7.0
# The Avengers                                   8.1
# The Dark Knight                                9.0

# %%
highest_rated_movies=data.nlargest(10,'Rating')[['Rank','Title','Year','Runtime (Minutes)', 'Rating','Director','Revenue (Millions)']].set_index('Title')

# %%
highest_rated_movies
# Out:
#                        Rank  Year  Runtime (Minutes)  Rating  \
# Title
# The Dark Knight          55  2008                152     9.0
# Inception                81  2010                148     8.8
# Dangal                  118  2016                161     8.8
# Interstellar             37  2014                169     8.6
# Kimi no na wa            97  2016                106     8.6
# The Intouchables        250  2011                112     8.6
# The Prestige             65  2006                130     8.5
# The Departed            100  2006                151     8.5
# The Dark Knight Rises   125  2012                164     8.5
# Whiplash                134  2014                107     8.5
#
#                                 Director  Revenue (Millions)
# Title
# The Dark Knight        Christopher Nolan              533.32
# Inception              Christopher Nolan              292.57
# Dangal                     Nitesh Tiwari               11.15
# ...

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='Director',y='Rating',data=highest_rated_movies)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(y=highest_rated_movies.index,x='Revenue (Millions)',hue='Director',dodge=False,data=highest_rated_movies)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.show()

# %%
#highest_rated_movies=data.nlargest(10,'Rating')[['Rank','Title','Year','Runtime (Minutes)', 'Rating','Director','Revenue (Millions)']].set_index('Title')

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
highest_rated_movies2=data.nlargest(10,'Revenue (Millions)')[['Rank','Title','Year','Runtime (Minutes)', 'Rating','Director','Revenue (Millions)']].set_index('Title')

# %%
highest_rated_movies2
# Out:
#                                             Rank  Year  Runtime (Minutes)  \
# Title
# Star Wars: Episode VII - The Force Awakens    51  2015                136
# Avatar                                        88  2009                162
# Jurassic World                                86  2015                124
# The Avengers                                  77  2012                143
# The Dark Knight                               55  2008                152
# Rogue One                                     13  2016                133
# Finding Dory                                 120  2016                 97
# Avengers: Age of Ultron                       95  2015                141
# The Dark Knight Rises                        125  2012                164
# The Hunger Games: Catching Fire              579  2013                146
#
#                                             Rating           Director  \
# Title
# ...

# %%
plt.figure(figsize=(8,4))
sns.barplot(y=highest_rated_movies.index,x='Revenue (Millions)',data=highest_rated_movies2)
plt.show()

# %%
data.nlargest(5,'Revenue (Millions)')['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# 87                                        Avatar
# 85                                Jurassic World
# 76                                  The Avengers
# 54                               The Dark Knight
# Name: Title, dtype: object

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False).plot(kind='barh')
# Out:
# <Axes: ylabel='Year'>

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2007    7.133962
# 2006    7.125000
# 2009    6.960784
# 2012    6.925000
# 2011    6.838095
# 2014    6.837755
# 2010    6.826667
# 2013    6.812088
# 2008    6.784615
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %%
data_rating=data.groupby('Rating')['Revenue (Millions)'].sum().sort_values(ascending=False).head(20)

# %%
data.groupby('Rating')['Revenue (Millions)'].sum().sort_values(ascending=False).head(20)
# Out:
# Rating
# 7.8    4869.916376
# 8.1    4377.572752
# 7.0    4288.799128
# 6.7    4183.131881
# 7.1    3876.748257
# 7.2    3665.822752
# 7.4    3458.099128
# 6.6    3188.375505
# 7.3    3182.369128
# 7.5    3008.506376
# 6.2    2964.149128
# 7.9    2870.379128
# 7.6    2713.570000
# 6.4    2638.201881
# 6.3    2602.818257
# 8.0    2540.560000
# 6.5    2446.972752
# 7.7    2423.932752
# 6.8    2222.765505
# 6.1    2072.381009
# Name: Revenue (Millions), dtype: float64

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
len(data[data['Genre'].str.contains('Action',case=False)])
# Out:
# 303

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['Rating_cat']=data['Rating'].apply(rating)

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
sns.countplot(x='Rating_cat',data=data)
# Out:
# <Axes: xlabel='Rating_cat', ylabel='count'>

# %%
data['Rating_cat'].value_counts()
# Out:
# Rating_cat
# Excellent    445
# Good         371
# Average      184
# Name: count, dtype: int64

# %%
data['Genre'].nunique()
# Out:
# 207

# %%
data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
# ...

# %%
one_d=[]
for item in list1:
   for item1 in item:
      one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
len(uni_list)
# Out:
# 20

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 513,
#          'Action': 303,
#          'Comedy': 279,
#          'Adventure': 259,
#          'Thriller': 195,
#          'Crime': 150,
#          'Romance': 141,
#          'Sci-Fi': 120,
#          'Horror': 119,
#          'Mystery': 106,
#          'Fantasy': 101,
#          'Biography': 81,
#          'Family': 51,
#          'Animation': 49,
#          'History': 29,
#          'Sport': 18,
#          'Music': 16,
#          'War': 13,
#          'Western': 7,
#          'Musical': 5})
